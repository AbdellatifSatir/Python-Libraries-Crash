# %%
import pandas as pd 
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt

# %%
sn.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
car_crashes = sn.load_dataset('car_crashes')
tips = sn.load_dataset('tips')
iris = sn.load_dataset('iris')
flights = sn.load_dataset('flights')

# %%
car_crashes.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %% [markdown]
# ## Distributions Plot

# %%
sn.distplot(car_crashes['total'])
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total', ylabel='Density'>

# %% [markdown]
# ## KDE Plot
# 'A kernel density estimate (KDE) plot is a method for visualizing the
# distribution of observations in a dataset, analagous to a histogram. KDE
# represents the data using a continuous probability density curve in one or
# more dimensions.'

# %%
sn.kdeplot(x='total',y='speeding',data=car_crashes)
# Out:
# <AxesSubplot:xlabel='total', ylabel='speeding'>

# %%
sn.kdeplot(car_crashes['total'])
# Out:
# <AxesSubplot:xlabel='total', ylabel='Density'>

# %% [markdown]
# ## Joint Plot
# Draw a plot of two variables with bivariate and univariate graphs.
#
# This function provides a convenient interface to the :class:`JointGrid`
# class, with several canned plot kinds. This is intended to be a fairly
# lightweight wrapper; if you need more flexibility, you should use
# :class:`JointGrid` directly.

# %%
sn.jointplot(car_crashes['alcohol'],car_crashes['speeding'],data=car_crashes)
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## Pair Plot
# 'Plot pairwise relationships in a dataset.
#
# By default, this function will create a grid of Axes such that each numeric
# variable in ``data`` will by shared across the y-axes across a single row and
# the x-axes across a single column. The diagonal plots are treated
# differently: a univariate distribution plot is drawn to show the marginal
# distribution of the data in each column.'

# %%
sn.set_style('darkgrid')

# %%
sn.pairplot(car_crashes)

# %%
sn.pairplot(tips, hue='sex')

# %% [markdown]
# ## Rug Plot
# Plot marginal distributions by drawing ticks along the x and y axes.
#
# This function is intended to complement other plots by showing the location
# of individual observations in an unobstrusive way.

# %%
sn.rugplot(tips['tip'])
# Out:
# <AxesSubplot:xlabel='tip'>

# %% [markdown]
# ## Styling

# %%
# sn.set_style('darkgrid')
# plt.figure(figsize=(8,4))
# sn.set_context()
# sn.despine()

# %% [markdown]
# # Categorical Data

# %% [markdown]
# ## Bar Plot
# Show point estimates and confidence intervals as rectangular bars.
#
# A bar plot represents an estimate of central tendency for a numeric
# variable with the height of each rectangle and provides some indication of
# the uncertainty around that estimate using error bars. Bar plots include 0
# in the quantitative axis range, and they are a good choice when 0 is a
# meaningful value for the quantitative variable, and you want to make
# comparisons against it.

# %%
sn.barplot(x='day',y='total_bill',data=tips,estimator=np.median)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# µ## Count Plot
# Show the counts of observations in each categorical bin using bars.

# %%
sn.countplot(x='sex',data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %% [markdown]
# ## Box Plot
# Draw a box plot to show distributions with respect to categories.

# %%
sn.boxplot(x='day',y='total_bill',data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sn.boxplot(x='day',y='total_bill',data=tips,hue='sex')
plt.legend(loc=2)

# %% [markdown]
# ## Violin Plot
# Draw a combination of boxplot and kernel density estimate.
#
# A violin plot plays a similar role as a box and whisker plot. It shows the
# distribution of quantitative data across several levels of one (or more)
# categorical variables such that those distributions can be compared. Unlike
# a box plot, in which all of the plot components correspond to actual
# datapoints, the violin plot features a kernel density estimation of the
# underlying distribution.

# %%
sn.violinplot(x='day',y='total_bill',data=tips,hue='sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ## Strip Plot
# Draw a scatterplot where one variable is categorical.
#
# A strip plot can be drawn on its own, but it is also a good complement
# to a box or violin plot in cases where you want to show all observations
# along with some representation of the underlying distribution.

# %%
sn.stripplot(x='day',y='total_bill',data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ## Swarm Plot
# Draw a categorical scatterplot with non-overlapping points.
#
# This function is similar to :func:`stripplot`, but the points are adjusted
# (only along the categorical axis) so that they don't overlap. This gives a
# better representation of the distribution of values, but it does not scale
# well to large numbers of observations. This style of plot is sometimes
# called a "beeswarm".

# %%
sn.swarmplot(x='day',y='total_bill',data=tips,hue='sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ## HeatMaps
# Plot rectangular data as a color-encoded matrix.
#
# This is an Axes-level function and will draw the heatmap into the
# currently-active Axes if none is provided to the ``ax`` argument.  Part of
# this Axes space will be taken and used to plot a colormap, unless ``cbar``
# is False or a separate Axes is provided to ``cbar_ax``.

# %%
mx = car_crashes.corr()
print(mx)
sn.heatmap(mx,cmap='Blues',linecolor='w',linewidth=1,annot=True)
# Out:
#                    total  speeding   alcohol  not_distracted  no_previous  \
# total           1.000000  0.611548  0.852613        0.827560     0.956179
# speeding        0.611548  1.000000  0.669719        0.588010     0.571976
# alcohol         0.852613  0.669719  1.000000        0.732816     0.783520
# not_distracted  0.827560  0.588010  0.732816        1.000000     0.747307
# no_previous     0.956179  0.571976  0.783520        0.747307     1.000000
# ins_premium    -0.199702 -0.077675 -0.170612       -0.174856    -0.156895
# ins_losses     -0.036011 -0.065928 -0.112547       -0.075970    -0.006359
#
#                 ins_premium  ins_losses
# total             -0.199702   -0.036011
# speeding          -0.077675   -0.065928
# alcohol           -0.170612   -0.112547
# not_distracted    -0.174856   -0.075970
# no_previous       -0.156895   -0.006359
# ins_premium        1.000000    0.623116
# ins_losses         0.623116    1.000000
# <AxesSubplot:>

# %%
pv = flights.pivot_table(index='month',columns='year',values='passengers')
print(pv)
sn.heatmap(pv)
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %% [markdown]
# ## Cluster Map
# Plot a matrix dataset as a hierarchically-clustered heatmap.

# %%
sn.clustermap(pv)

# %% [markdown]
# ## PairGrid
# Subplot grid for plotting pairwise relationships in a dataset.
#
# This object maps each variable in a dataset onto a column and row in a
# grid of multiple axes. Different axes-level plotting functions can be
# used to draw bivariate plots in the upper and lower triangles, and the
# the marginal distribution of each variable can be shown on the diagonal.

# %%
iris
iris_g = sn.PairGrid(iris,hue='species')
iris_g.map(plt.scatter) #Plot with the same function in every subplot.
iris_g.map_diag(sn.histplot) #Plot with a univariate function on each diagonal subplot.
iris_g.add_legend()

# %% [markdown]
# ## FacetGrid
# Multi-plot grid for plotting conditional relationships.

# %%
tips_fg = sn.FacetGrid(tips,col='time',hue='smoker')
tips_fg.map(sn.histplot,'total_bill')
tips_fg.map(plt.scatter,'total_bill','tip')

# %% [markdown]
# ## Regression
# Plot data and regression model fits across a FacetGrid.
#
# This function combines :func:`regplot` and :class:`FacetGrid`. It is
# intended as a convenient interface to fit regression models across
# conditional subsets of a dataset

# %%
sn.lmplot(x='total_bill',y='tip',data=tips,hue='sex',markers=['.','+'])

# %%
sn.lmplot(x='total_bill',y='tip',hue='sex',row='smoker',data=tips)
