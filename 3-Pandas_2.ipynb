# %%
import pandas as pd

# %%
data = pd.read_csv(r'C:\Users\pc\Downloads\csc_member.csv')
data.head()
# Out:
#                     Horodateur         Full name                       Email  \
# 0  2022/09/29 4:10:57 PM UTC+1    AMER Yassmine   yassmine.amer.22@gmail.com
# 1  2022/09/29 4:11:33 PM UTC+1       NADDI DOUAE       douaenaddi2@gmail.com
# 2  2022/09/29 4:29:36 PM UTC+1     Asselgui Omar        asgomar115@gmail.com
# 3  2022/09/29 4:38:46 PM UTC+1  Yassine AHANNACH  yassineahannach5@gmail.com
# 4  2022/09/29 4:39:22 PM UTC+1    Boutaina difa    boutainadifa631@gmail.com
#
#   Phone number What is your level? Where did you hear about us?  \
# 0   0636288113               GSTR2                     Facebook
# 1   0640679204                 AP2                    Instagram
# 2   0602098083                 AP1                    Instagram
# 3   0617252679                 AP2           Instagram;Facebook
# 4   0652046132                 AP1                          NaN
#
#                          What are you interested in?  \
# 0            Web developpement;Cyber Security;Design
# ...

# %%
data.columns
# Out:
# Index(['Horodateur', 'Full name', 'Email', 'Phone number',
#        'What is your level?', 'Where did you hear about us?',
#        'What are you interested in?', 'Any comments you want to tell us?'],
#       dtype='object')

# %%
data = data.drop(columns=['Any comments you want to tell us?'])
data.head()
# Out:
#                     Horodateur         Full name                       Email  \
# 0  2022/09/29 4:10:57 PM UTC+1    AMER Yassmine   yassmine.amer.22@gmail.com
# 1  2022/09/29 4:11:33 PM UTC+1       NADDI DOUAE       douaenaddi2@gmail.com
# 2  2022/09/29 4:29:36 PM UTC+1     Asselgui Omar        asgomar115@gmail.com
# 3  2022/09/29 4:38:46 PM UTC+1  Yassine AHANNACH  yassineahannach5@gmail.com
# 4  2022/09/29 4:39:22 PM UTC+1    Boutaina difa    boutainadifa631@gmail.com
#
#   Phone number What is your level? Where did you hear about us?  \
# 0   0636288113               GSTR2                     Facebook
# 1   0640679204                 AP2                    Instagram
# 2   0602098083                 AP1                    Instagram
# 3   0617252679                 AP2           Instagram;Facebook
# 4   0652046132                 AP1                          NaN
#
#                          What are you interested in?
# 0            Web developpement;Cyber Security;Design
# ...

# %%
data['Interested in'] = data['What are you interested in?']
data['Coming from'] = data['Where did you hear about us?']
data = data.drop(columns='What are you interested in?')
data = data.drop(columns='Where did you hear about us?')
data.head()
# Out:
#                     Horodateur         Full name                       Email  \
# 0  2022/09/29 4:10:57 PM UTC+1    AMER Yassmine   yassmine.amer.22@gmail.com
# 1  2022/09/29 4:11:33 PM UTC+1       NADDI DOUAE       douaenaddi2@gmail.com
# 2  2022/09/29 4:29:36 PM UTC+1     Asselgui Omar        asgomar115@gmail.com
# 3  2022/09/29 4:38:46 PM UTC+1  Yassine AHANNACH  yassineahannach5@gmail.com
# 4  2022/09/29 4:39:22 PM UTC+1    Boutaina difa    boutainadifa631@gmail.com
#
#   Phone number What is your level?  \
# 0   0636288113               GSTR2
# 1   0640679204                 AP2
# 2   0602098083                 AP1
# 3   0617252679                 AP2
# 4   0652046132                 AP1
#
#                                        Interested in         Coming from
# 0            Web developpement;Cyber Security;Design            Facebook
# 1  Web developpement;Data science;Competitive pro...           Instagram
# ...

# %%
#data = data.drop(columns='What are you interested in?')
#data = data.drop(columns='Where did you hear about us?')
data.head()
# Out:
#                     Horodateur         Full name                       Email  \
# 0  2022/09/29 4:10:57 PM UTC+1    AMER Yassmine   yassmine.amer.22@gmail.com
# 1  2022/09/29 4:11:33 PM UTC+1       NADDI DOUAE       douaenaddi2@gmail.com
# 2  2022/09/29 4:29:36 PM UTC+1     Asselgui Omar        asgomar115@gmail.com
# 3  2022/09/29 4:38:46 PM UTC+1  Yassine AHANNACH  yassineahannach5@gmail.com
# 4  2022/09/29 4:39:22 PM UTC+1    Boutaina difa    boutainadifa631@gmail.com
#
#   Phone number What is your level?  \
# 0   0636288113               GSTR2
# 1   0640679204                 AP2
# 2   0602098083                 AP1
# 3   0617252679                 AP2
# 4   0652046132                 AP1
#
#                                        Interested in         Coming from
# 0            Web developpement;Cyber Security;Design            Facebook
# 1  Web developpement;Data science;Competitive pro...           Instagram
# ...

# %%
data[data.isna().any(axis=1)]
data[data['Coming from'].isnull()].count()
data[data['Coming from'].isnull()]
# Out:
#                        Horodateur             Full name  \
# 4     2022/09/29 4:39:22 PM UTC+1        Boutaina difa
# 14    2022/09/29 5:22:31 PM UTC+1       Soukaina Soudi
# 21    2022/09/29 6:07:03 PM UTC+1            Safaesahih
# 26    2022/09/29 6:08:45 PM UTC+1      Salma Khamlichi
# 29    2022/09/29 6:10:01 PM UTC+1           SAMODI Adam
# 57    2022/09/29 7:10:44 PM UTC+1  Chaymae El Khartouti
# 65    2022/09/29 8:16:55 PM UTC+1          Omayma nayma
# 81   2022/09/30 11:22:20 AM UTC+1         Achraf Tahiri
# 85    2022/09/30 1:19:27 PM UTC+1      Imane el affassi
# 87    2022/09/30 4:16:49 PM UTC+1      Nasrallah Fadili
# 88    2022/09/30 4:17:44 PM UTC+1       El arabi haitam
# 93    2022/09/30 5:25:04 PM UTC+1      Bassma elhllafi
# 101   2022/09/30 9:10:31 PM UTC+1    Assaad El Ayddouni
# 108  2022/09/30 10:48:10 PM UTC+1         Ilyas Elrhoul
#
#                              Email Phone number What is your level?  \
# ...

# %%
data[data['Coming from'].isnull()]['Coming from']
data['Coming from'].isnull().sum()
# Out:
# 14

# %%
data.loc[data['Coming from'].isnull() , 'Coming from'] = 'unknown'

# %%
data['Coming from'].isnull().sum()
# Out:
# 0

# %%
data.head()
# Out:
#                     Horodateur         Full name                       Email  \
# 0  2022/09/29 4:10:57 PM UTC+1    AMER Yassmine   yassmine.amer.22@gmail.com
# 1  2022/09/29 4:11:33 PM UTC+1       NADDI DOUAE       douaenaddi2@gmail.com
# 2  2022/09/29 4:29:36 PM UTC+1     Asselgui Omar        asgomar115@gmail.com
# 3  2022/09/29 4:38:46 PM UTC+1  Yassine AHANNACH  yassineahannach5@gmail.com
# 4  2022/09/29 4:39:22 PM UTC+1    Boutaina difa    boutainadifa631@gmail.com
#
#   Phone number What is your level?  \
# 0   0636288113               GSTR2
# 1   0640679204                 AP2
# 2   0602098083                 AP1
# 3   0617252679                 AP2
# 4   0652046132                 AP1
#
#                                        Interested in         Coming from
# 0            Web developpement;Cyber Security;Design            Facebook
# 1  Web developpement;Data science;Competitive pro...           Instagram
# ...

# %%
data['Interested in'].iloc[1]
# Out:
# 'Web developpement;Data science;Competitive programming (problem solving);Cyber Security'

# %%
data = data.rename(columns={"What is your level?": "Level"})
data.head()
# Out:
#                     Horodateur         Full name                       Email  \
# 0  2022/09/29 4:10:57 PM UTC+1    AMER Yassmine   yassmine.amer.22@gmail.com
# 1  2022/09/29 4:11:33 PM UTC+1       NADDI DOUAE       douaenaddi2@gmail.com
# 2  2022/09/29 4:29:36 PM UTC+1     Asselgui Omar        asgomar115@gmail.com
# 3  2022/09/29 4:38:46 PM UTC+1  Yassine AHANNACH  yassineahannach5@gmail.com
# 4  2022/09/29 4:39:22 PM UTC+1    Boutaina difa    boutainadifa631@gmail.com
#
#   Phone number  Level                                      Interested in  \
# 0   0636288113  GSTR2            Web developpement;Cyber Security;Design
# 1   0640679204    AP2  Web developpement;Data science;Competitive pro...
# 2   0602098083    AP1  Web developpement;Data science;Competitive pro...
# 3   0617252679    AP2  Web developpement;Data science;Cyber Security;...
# 4   0652046132    AP1                                  Web developpement
#
#           Coming from
# 0            Facebook
# ...

# %%
cols = list(data.columns)
data = data[cols[0:3]+[cols[-1]]+cols[-3:-1]]

# %%
data.sort_values('Full name',ignore_index=True).head()
# Out:
#                      Horodateur         Full name  \
# 0   2022/09/29 7:00:59 PM UTC+1                 ?
# 1  2022/09/29 10:28:37 PM UTC+1   AL AZAMI TAREK
# 2   2022/09/29 4:10:57 PM UTC+1    AMER Yassmine
# 3   2022/09/30 4:18:51 PM UTC+1  Abdellah esseidi
# 4   2022/09/29 4:56:32 PM UTC+1   Abetiou Sofiane
#
#                          Email  Level  \
# 0       khalil.elcr7@gmail.com    AP1
# 1  tarek.alazami@etu.uae.ac.ma    AP2
# 2   yassmine.amer.22@gmail.com  GSTR2
# 3    esseidiabdellah@gmail.com    AP1
# 4     sofianeabetiou@gmail.com  GINF1
#
#                                        Interested in         Coming from
# 0  Web developpement;Data science;Competitive pro...  La foire des clubs
# 1                           Web developpement;Design           Instagram
# 2            Web developpement;Cyber Security;Design            Facebook
# 3                                  Web developpement  La foire des clubs
# ...

# %%
data.describe()
# Out:
#                          Horodateur       Full name  \
# count                           118             118
# unique                          118             118
# top     2022/09/29 4:10:57 PM UTC+1  AMER Yassmine
# freq                              1               1
#
#                              Email Level  \
# count                          118   118
# unique                         118     7
# top     yassmine.amer.22@gmail.com   AP1
# freq                             1    87
#
#                                             Interested in Coming from
# count                                                 118         118
# unique                                                 29          29
# top     Web developpement;Data science;Competitive pro...   Instagram
# freq                                                   20          26

# %%
data.groupby('Level').count()
# Out:
#        Horodateur  Full name  Email  Interested in  Coming from
# Level
# AP1            87         87     87             87           87
# AP2            16         16     16             16           16
# GIL1            3          3      3              3            3
# GINF1           7          7      7              7            7
# GSEA1           1          1      1              1            1
# GSTR1           2          2      2              2            2
# GSTR2           2          2      2              2            2

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = [level for level,df in data.groupby('Level')]
y = data.groupby('Level').count()['Full name']
plt.bar(x,y)
# Out:
# <BarContainer object of 7 artists>

# %%
plt.pie(y,labels=x, autopct='%.0f %%',radius=1.2)
plt.show()

# %%
data.head()
# Out:
#                     Horodateur         Full name                       Email  \
# 0  2022/09/29 4:10:57 PM UTC+1    AMER Yassmine   yassmine.amer.22@gmail.com
# 1  2022/09/29 4:11:33 PM UTC+1       NADDI DOUAE       douaenaddi2@gmail.com
# 2  2022/09/29 4:29:36 PM UTC+1     Asselgui Omar        asgomar115@gmail.com
# 3  2022/09/29 4:38:46 PM UTC+1  Yassine AHANNACH  yassineahannach5@gmail.com
# 4  2022/09/29 4:39:22 PM UTC+1    Boutaina difa    boutainadifa631@gmail.com
#
#    Level                                      Interested in  \
# 0  GSTR2            Web developpement;Cyber Security;Design
# 1    AP2  Web developpement;Data science;Competitive pro...
# 2    AP1  Web developpement;Data science;Competitive pro...
# 3    AP2  Web developpement;Data science;Cyber Security;...
# 4    AP1                                  Web developpement
#
#           Coming from
# 0            Facebook
# 1           Instagram
# 2           Instagram
# 3  Instagram;Facebook
# 4             unknown

# %%
data.shape
# Out:
# (118, 6)

# %%
data.groupby(data['Interested in'].str.contains('Data science')).count()
# Out:
#                Horodateur  Full name  Email  Level  Interested in  Coming from
# Interested in
# False                  56         56     56     56             56           56
# True                   62         62     62     62             62           62

# %%
lis = [
    'Web developpement','Cyber Security','Design','Data science',
    'Game developpement' , 'problem solving'
    #,'Competitive programming (problem solving)'
]
s = 0
for i in range(len(lis)):
    s = s + data.groupby(data['Interested in'].str.contains(lis[i])).count()['Email'][1]
    print(lis[i] , ' : ' , data.groupby(data['Interested in'].str.contains(lis[i])).count()['Email'][1])
print(s)
# Out:
# Web developpement  :  82
# Cyber Security  :  67
# Design  :  53
# Data science  :  62
# Game developpement  :  1
# problem solving  :  63
# 328

# %%
data.loc[data['Interested in'] == 'Competitive programming (problem solving)' , 'Interested in'] = 'problem solving'

# %%
data.groupby(data['Interested in'].str.contains('problem solving')).count()
# Out:
#                Horodateur  Full name  Email  Level  Interested in  Coming from
# Interested in
# False                  55         55     55     55             55           55
# True                   63         63     63     63             63           63

# %%
data.head()
# Out:
#                     Horodateur         Full name                       Email  \
# 0  2022/09/29 4:10:57 PM UTC+1    AMER Yassmine   yassmine.amer.22@gmail.com
# 1  2022/09/29 4:11:33 PM UTC+1       NADDI DOUAE       douaenaddi2@gmail.com
# 2  2022/09/29 4:29:36 PM UTC+1     Asselgui Omar        asgomar115@gmail.com
# 3  2022/09/29 4:38:46 PM UTC+1  Yassine AHANNACH  yassineahannach5@gmail.com
# 4  2022/09/29 4:39:22 PM UTC+1    Boutaina difa    boutainadifa631@gmail.com
#
#    Level                                      Interested in  \
# 0  GSTR2            Web developpement;Cyber Security;Design
# 1    AP2  Web developpement;Data science;Competitive pro...
# 2    AP1  Web developpement;Data science;Competitive pro...
# 3    AP2  Web developpement;Data science;Cyber Security;...
# 4    AP1                                  Web developpement
#
#           Coming from
# 0            Facebook
# 1           Instagram
# 2           Instagram
# 3  Instagram;Facebook
# 4             unknown

# %%
data.rename(columns={'Horodateur':'Date'},inplace=True)

# %%
pd.set_option('display.max_rows',120)
data
# Out:
#                          Date                     Full name  \
# 0   2022-09-29 16:10:57-01:00                AMER Yassmine
# 1   2022-09-29 16:11:33-01:00                   NADDI DOUAE
# 2   2022-09-29 16:29:36-01:00                 Asselgui Omar
# 3   2022-09-29 16:38:46-01:00              Yassine AHANNACH
# 4   2022-09-29 16:39:22-01:00                Boutaina difa
# 5   2022-09-29 16:42:24-01:00              Boussaid Meryeme
# 6   2022-09-29 16:45:54-01:00                 Hasni Naoufal
# 7   2022-09-29 16:46:11-01:00                   Aya Hassoun
# 8   2022-09-29 16:53:02-01:00          Salah eddine bouabid
# 9   2022-09-29 16:53:11-01:00           Yassine El Basraoui
# 10  2022-09-29 16:56:32-01:00               Abetiou Sofiane
# 11  2022-09-29 17:00:17-01:00              ZAKARIA ASSADIKI
# 12  2022-09-29 17:13:08-01:00           Abouabdellah Mouad
# 13  2022-09-29 17:16:23-01:00               Ibrahimi Maryam
# 14  2022-09-29 17:22:31-01:00               Soukaina Soudi
# ...

# %%
data['Date'] = pd.to_datetime(data['Date'])

# %%
data.dtypes
# Out:
# Date             datetime64[ns, pytz.FixedOffset(-60)]
# Full name                                       object
# Email                                           object
# Level                                           object
# Interested in                                   object
# Coming from                                     object
# dtype: object

# %%
data['Date'].dt.month
# Out:
# 0       9
# 1       9
# 2       9
# 3       9
# 4       9
#        ..
# 113     9
# 114    10
# 115    10
# 116    10
# 117    10
# Name: Date, Length: 118, dtype: int64

# %%
#data.to_csv('csc.csv',index=False)

# %%
pd.read_csv('csc.csv')
# Out:
#                           Date                     Full name  \
# 0    2022-09-29 16:10:57-01:00                AMER Yassmine
# 1    2022-09-29 16:11:33-01:00                   NADDI DOUAE
# 2    2022-09-29 16:29:36-01:00                 Asselgui Omar
# 3    2022-09-29 16:38:46-01:00              Yassine AHANNACH
# 4    2022-09-29 16:39:22-01:00                Boutaina difa
# 5    2022-09-29 16:42:24-01:00              Boussaid Meryeme
# 6    2022-09-29 16:45:54-01:00                 Hasni Naoufal
# 7    2022-09-29 16:46:11-01:00                   Aya Hassoun
# 8    2022-09-29 16:53:02-01:00          Salah eddine bouabid
# 9    2022-09-29 16:53:11-01:00           Yassine El Basraoui
# 10   2022-09-29 16:56:32-01:00               Abetiou Sofiane
# 11   2022-09-29 17:00:17-01:00              ZAKARIA ASSADIKI
# 12   2022-09-29 17:13:08-01:00           Abouabdellah Mouad
# 13   2022-09-29 17:16:23-01:00               Ibrahimi Maryam
# ...

# %%
ds = 0
l = data['Interested in']
ll = l.str.contains('Web developpement')

for i in range(len(l)):
    if ll==True:
        ds=ds+1
print(ds)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [128], in <cell line: 5>()
#       3 ll = l.str.contains('Web developpement')
#       5 for i in range(len(l)):
# ----> 6     if ll==True:
#       7         ds=ds+1
#       8 print(ds)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self):
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530     )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
l.str.contains('Web developpement')
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# 5       True
# 6       True
# 7       True
# 8       True
# 9       True
# 10      True
# 11      True
# 12     False
# 13     False
# 14      True
# 15     False
# 16      True
# 17     False
# 18      True
# 19      True
# 20     False
# 21     False
# 22      True
# 23     False
# 24     False
# 25      True
# 26      True
# 27      True
# 28      True
# 29     False
# 30      True
# 31      True
# 32      True
# 33     False
# 34     False
# 35      True
# 36     False
# 37      True
# 38     False
# 39      True
# 40      True
# 41     False
# 42      True
# 43      True
# 44      True
# 45      True
# 46      True
# 47     False
# 48     False
# 49      True
# 50      True
# 51     False
# 52      True
# 53      True
# 54      True
# 55      True
# 56      True
# 57     False
# 58      True
# 59      True
# 60     False
# 61     False
# 62      True
# 63      True
# 64     False
# 65      True
# ...
